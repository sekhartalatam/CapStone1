# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
df = pd.read_csv("Airline Quality Ratings.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129880.000000
# mean       15.091129                                3.057599
# std        38.465650                                1.526741
# min         0.000000                                0.000000
# ...

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'ID'}>, <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Flight Distance'}>,
#         <Axes: title={'center': 'Departure Delay'}>],
#        [<Axes: title={'center': 'Arrival Delay'}>,
#         <Axes: title={'center': 'Departure and Arrival Time Convenience'}>,
#         <Axes: title={'center': 'Ease of Online Booking'}>,
#         <Axes: title={'center': 'Check-in Service'}>],
#        [<Axes: title={'center': 'Online Boarding'}>,
#         <Axes: title={'center': 'Gate Location'}>,
#         <Axes: title={'center': 'On-board Service'}>,
#         <Axes: title={'center': 'Seat Comfort'}>],
#        [<Axes: title={'center': 'Leg Room Service'}>,
#         <Axes: title={'center': 'Cleanliness'}>,
#         <Axes: title={'center': 'Food and Drink'}>,
#         <Axes: title={'center': 'In-flight Service'}>],
#        [<Axes: title={'center': 'In-flight Wifi Service'}>,
#         <Axes: title={'center': 'In-flight Entertainment'}>,
# ...

# %%
df.isnull().sum()*100/df.isnull().count()
# Out:
# ID                                        0.000000
# Gender                                    0.000000
# Age                                       0.000000
# Customer Type                             0.000000
# Type of Travel                            0.000000
# Class                                     0.000000
# Flight Distance                           0.000000
# Departure Delay                           0.000000
# Arrival Delay                             0.302587
# Departure and Arrival Time Convenience    0.000000
# Ease of Online Booking                    0.000000
# Check-in Service                          0.000000
# Online Boarding                           0.000000
# Gate Location                             0.000000
# On-board Service                          0.000000
# Seat Comfort                              0.000000
# Leg Room Service                          0.000000
# Cleanliness                               0.000000
# ...

# %%
df['Satisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Passenger satification proportion in the dataset")
plt.show()

# %%
# Specify the names of the columns you want to extract
required_columns = ['Satisfaction', 'In-flight Entertainment']
# Extract data from the specified columns
selected_columns = df[required_columns]

selected_columns.head()
# Out:
#               Satisfaction  In-flight Entertainment
# 0  Neutral or Dissatisfied                        5
# 1                Satisfied                        5
# 2                Satisfied                        3
# 3                Satisfied                        5
# 4                Satisfied                        3

# %%
from scipy.stats import chi2_contingency

# Create a contingency table of the two variables
contingency_table = pd.crosstab(df['Satisfaction'], df['In-flight Entertainment'])
contingency_table.head()
# Out:
# In-flight Entertainment   0      1      2      3      4      5
# Satisfaction
# Neutral or Dissatisfied  18  13450  17296  17360  14307  11021
# Satisfied                 0   2225   4672   6524  22484  20523

# %%
# Apply the chi-squared test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-squared statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies table:")
print(expected)
# Out:
# Chi-squared statistic: 23071.602435454988
# P-value: 0.0
# Degrees of freedom: 5
# Expected frequencies table:
# [[1.01796735e+01 8.86479905e+03 1.24237260e+04 1.35072957e+04
#   2.08066872e+04 1.78393123e+04]
#  [7.82032646e+00 6.81020095e+03 9.54427398e+03 1.03767043e+04
#   1.59843128e+04 1.37046877e+04]]

# %% [markdown]
# ## The null hypothesis (H0) for the chi-squared test of independence in this context is:
#
# There is no significant association between passenger satisfaction and In-flight Entertainment airline services.
# The null hypothesis states that the observed frequencies of passenger satisfaction levels and In-flight Entertainment
# ratings are not dependent on each other.
